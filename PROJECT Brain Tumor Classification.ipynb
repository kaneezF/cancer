# %% [markdown]
# ### Load Modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Prepare/collect data

# %%
import os
path = os.listdir('C:\\Users\\Admin\\Desktop\\brain\\Training')
classes = {'notumor':0, 'pituitary':1}

# %%
import cv2
X = []
Y = []
for cls in classes:
    pth = 'C:\\Users\\Admin\\Desktop\\brain\\Training\\'+cls
    for j in os.listdir(pth):
        img = cv2.imread(pth+'/'+j, 0)
        img = cv2.resize(img, (200,200))
        X.append(img)
        Y.append(classes[cls])

# %%
X = np.array(X)
Y = np.array(Y)

X_updated = X.reshape(len(X), -1)

# %%
np.unique(Y)
# Out:
# array([0, 1])

# %%
pd.Series(Y).value_counts()
# Out:
# 0    1595
# 1    1457
# Name: count, dtype: int64

# %%
X.shape, X_updated.shape
# Out:
# ((3052, 200, 200), (3052, 40000))

# %% [markdown]
# ### Visualize data

# %%
plt.imshow(X[0], cmap='gray')

# %% [markdown]
# ### Prepare data

# %%
X_updated = X.reshape(len(X), -1)
X_updated.shape
# Out:
# (3052, 40000)

# %% [markdown]
# ### Split Data

# %%
xtrain, xtest, ytrain, ytest = train_test_split(X_updated, Y, random_state=10,
                                               test_size=.20)

# %%
xtrain.shape, xtest.shape
# Out:
# ((2441, 40000), (611, 40000))

# %% [markdown]
# ### Feature Scaling

# %%
print(xtrain.max(), xtrain.min())
print(xtest.max(), xtest.min())
xtrain = xtrain/255
xtest = xtest/255
print(xtrain.max(), xtrain.min())
print(xtest.max(), xtest.min())
# Out:
# 255 0
# 255 0
# 1.0 0.0
# 1.0 0.0

# %% [markdown]
# ### Feature Selection: PCA

# %%
from sklearn.decomposition import PCA

# %%
print(xtrain.shape, xtest.shape)

pca = PCA(.98)
# pca_train = pca.fit_transform(xtrain)
# pca_test = pca.transform(xtest)
pca_train = xtrain
pca_test = xtest
# Out:
# (2441, 40000) (611, 40000)

# %%
# print(pca_train.shape, pca_test.shape)
# print(pca.n_components_)
# print(pca.n_features_)

# %% [markdown]
# ### Train Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# %%
import warnings
warnings.filterwarnings('ignore')

lg = LogisticRegression(C=0.1)
lg.fit(xtrain, ytrain)
# Out:
# LogisticRegression(C=0.1)

# %%
sv = SVC()
sv.fit(xtrain, ytrain)
# Out:
# SVC()

# %% [markdown]
# ### Evaluation

# %%
print("Training Score:", lg.score(xtrain, ytrain))
print("Testing Score:", lg.score(xtest, ytest))
# Out:
# Training Score: 1.0
# Testing Score: 0.983633387888707

# %%
print("Training Score:", sv.score(xtrain, ytrain))
print("Testing Score:", sv.score(xtest, ytest))
# Out:
# Training Score: 0.9938549774682507
# Testing Score: 0.983633387888707

# %% [markdown]
# ### Prediction

# %%
pred = sv.predict(xtest)

# %%
misclassified=np.where(ytest!=pred)
misclassified
# Out:
# (array([  7,  83,  99, 247, 262, 284, 333, 468, 485, 550], dtype=int64),)

# %%
print("Total Misclassified Samples: ",len(misclassified[0]))
print(pred[36],ytest[36])
# Out:
# Total Misclassified Samples:  10
# 0 0

# %% [markdown]
# ### TEST MODEL

# %%
dec = {0:'No Tumor', 1:'Positive Tumor'}

# %%
plt.figure(figsize=(12,8))
p = os.listdir('C:\\Users\\Admin\\Desktop\\brain\\Testing')
c=1
for i in os.listdir('C:\\Users\\Admin\\Desktop\\brain\\Testing\\notumor')[:9]:
    plt.subplot(3,3,c)
    
    img = cv2.imread('C:\\Users\\Admin\\Desktop\\brain\\Testing\\notumor'+i,0)
    img1 = cv2.resize(img, (200,200))
    img1 = img1.reshape(1,-1)/255
    p = sv.predict(img1)
    plt.title(dec[p[0]])
    plt.imshow(img, cmap='gray')
    plt.axis('off')
    c+=1
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[40], line 8
#       5 plt.subplot(3,3,c)
#       7 img = cv2.imread('C:\\Users\\Admin\\Desktop\\brain\\Testing\\notumor'+i,0)
# ----> 8 img1 = cv2.resize(img, (200,200))
#       9 img1 = img1.reshape(1,-1)/255
#      10 p = sv.predict(img1)
#
# error: OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4152: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'

# %%
plt.figure(figsize=(12,8))
p = os.listdir('brain_tumor/Testing/')
c=1
for i in os.listdir('brain_tumor/Testing/pituitary_tumor/')[:16]:
    plt.subplot(4,4,c)
    
    img = cv2.imread('brain_tumor/Testing/pituitary_tumor/'+i,0)
    img1 = cv2.resize(img, (200,200))
    img1 = img1.reshape(1,-1)/255
    p = sv.predict(img1)
    plt.title(dec[p[0]])
    plt.imshow(img, cmap='gray')
    plt.axis('off')
    c+=1
